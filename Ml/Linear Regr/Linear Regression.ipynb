# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('Area(sqr ft)')
plt.ylabel('Prices($)')
plt.scatter(df.area,df.price,color='green',marker='^')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg=linear_model.LinearRegression()
print(reg.fit(df[['area']],df.price))
# Out:
# LinearRegression()

# %%
reg.predict([[4000]])
# Out:
# C:\Users\hp\anaconda3\envs\virtual_environment_name\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([723767.12328767])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*4000+180616.43835616432
# Out:
# 723767.1232761643

# %%
d=pd.read_csv('areas.csv')
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=reg.predict(d)

# %%
d['prices']=p

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv('priceprediction.csv',index=False)

# %%
#save and train model using pickle

# %%
import pickle

# %%
with open('saved_lmodel','wb') as file:
    pickle.dump(reg,file)

# %%
# opening saved file
with open('saved_lmodel','rb') as f:
    model=pickle.load(f)

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.predict([[3456]])
# Out:
# C:\Users\hp\anaconda3\envs\virtual_environment_name\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([649898.63013699])

# %%
from joblib import dump,load

# %%
with open("filename.pkl", "wb") as f:
    dump(reg,f)

# %%
with open("filename.pkl", "rb") as f:
    model2=load(f)

# %%
model2.coef_
# Out:
# array([135.78767123])

# %%
model2.predict([[10000]])
# Out:
# C:\Users\hp\anaconda3\envs\virtual_environment_name\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1538493.15068493])
