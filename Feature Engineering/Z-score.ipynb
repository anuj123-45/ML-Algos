# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
df=pd.read_csv('heights (1).csv')

# %%
df.shape
# Out:
# (10000, 2)

# %%
df.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
plt.hist(df.height, bins=20, rwidth=0.8)
plt.xlabel('Height (inches)')
plt.ylabel('Count')
plt.show()

# %%
plt.boxplot(df['height'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e1ddf9faf0>,
#   <matplotlib.lines.Line2D at 0x1e1ddf9ffa0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e1ddf9d7b0>,
#   <matplotlib.lines.Line2D at 0x1e1ddf9cc40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e1ddf9ed40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e1ddf9e1d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e1ddf9f7c0>],
#  'means': []}

# %%
from scipy.stats import norm
import numpy as np
plt.hist(df.height, bins=20, rwidth=0.8, density=True)
plt.xlabel('Height (inches)')
plt.ylabel('Count')

rng = np.arange(df.height.min(), df.height.max(), 0.1)
plt.plot(rng, norm.pdf(rng,df.height.mean(),df.height.std()))

# %%
df.height.mean()
# Out:
# 66.367559754866

# %%
df.height.std()
# Out:
# 3.847528120795573

# %%
# 3standard deviation
upper_limit=df.height.mean()+3*df.height.std()
upper_limit
# Out:
# 77.91014411725271

# %%
lower_limit=df.height.mean()-3*df.height.std()
lower_limit
# Out:
# 54.824975392479274

# %%
df[(df.height>upper_limit) | (df.height<lower_limit)]
# Out:
#       gender     height
# 994     Male  78.095867
# 1317    Male  78.462053
# 2014    Male  78.998742
# 3285    Male  78.528210
# 3757    Male  78.621374
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
df_new=df[(df.height<upper_limit) & ((df.height>lower_limit))]

# %%
df_new.head()
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796

# %%
df_new.shape
# Out:
# (9993, 2)

# %%
#z-score:  it  tells how many standard devaitions u are away from mean

# %%
df['z-score']=(df.height-df.height.mean())/df.height.std()

# %%
df.tail(5)
# Out:
#       gender     height   z-score
# 9995  Female  66.172652 -0.050658
# 9996  Female  67.067155  0.181830
# 9997  Female  63.867992 -0.649655
# 9998  Female  69.034243  0.693090
# 9999  Female  61.944246 -1.149651

# %%
df[df['z-score']<-3]
# Out:
#       gender     height   z-score
# 6624  Female  54.616858 -3.054091
# 9285  Female  54.263133 -3.146027

# %%
df[df['z-score']>3]
# Out:
#      gender     height   z-score
# 994    Male  78.095867  3.048271
# 1317   Male  78.462053  3.143445
# 2014   Male  78.998742  3.282934
# 3285   Male  78.528210  3.160640
# 3757   Male  78.621374  3.184854
