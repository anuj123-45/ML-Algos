# %%
import pandas as pd

# %%
df=pd.read_csv('AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# on base of price
min_price,max_price=(df['price']).quantile([0.01,0.999])

# %%
min_price,max_price
# Out:
# (30.0, 3000.0)

# %%
df2=df[(df['price']>min_price_per_night) & (df['price']<max_price_per_night)]

# %%
df2.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 6  5121                                   BlissArtsSpace!     7356
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 2    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df2.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.909900e+04  3.909900e+04  39099.000000  39099.000000  39099.000000
# mean   1.876133e+07  6.574100e+07     40.727551    -73.947082     98.090897
# std    1.080673e+07  7.650420e+07      0.057401      0.047128     44.420514
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.440949e+06  7.858308e+06     40.687270    -73.977375     60.000000
# 50%    1.934671e+07  3.091859e+07     40.719050    -73.951530     90.000000
# 75%    2.843882e+07  1.037360e+08     40.764120    -73.929640    130.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990    199.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    39099.000000       39099.000000       31915.000000
# mean         6.743037          25.030103           1.396984
# std         20.114359          46.725853           1.724181
# ...

# %%
# on base of nights
min_nights,max_nights=(df['minimum_nights']).quantile([0.01,0.99])

# %%
min_nights,max_nights
# Out:
# (1.0, 45.0)

# %%
df3=df[(df['minimum_nights']>min_nights) & (df['minimum_nights']<max_nights)]

# %%
df3.head()
# Out:
#      id                                              name  host_id  host_name  \
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192      Laura
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322      Chris
# 7  5178                  Large Furnished Room Near B'way      8967   Shunichi
# 8  5203                Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 2           Manhattan           Harlem  40.80902  -73.94190     Private room
# 4           Manhattan      East Harlem  40.79851  -73.94399  Entire home/apt
# 5           Manhattan      Murray Hill  40.74767  -73.97500  Entire home/apt
# 7           Manhattan   Hell's Kitchen  40.76489  -73.98493     Private room
# 8           Manhattan  Upper West Side  40.80178  -73.96723     Private room
#
# ...

# %%
df3.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.567400e+04  3.567400e+04  35674.000000  35674.000000  35674.000000
# mean   1.873687e+07  6.202252e+07     40.728202    -73.955001    155.021220
# std    1.097532e+07  7.541904e+07      0.053463      0.042214    204.012279
# min    3.647000e+03  2.571000e+03     40.499790    -74.244420      0.000000
# 25%    9.317318e+06  6.556741e+06     40.689910    -73.983250     70.000000
# 50%    1.941453e+07  2.579193e+07     40.721780    -73.956810    119.000000
# 75%    2.868228e+07  9.571768e+07     40.762057    -73.938920    185.000000
# max    3.648724e+07  2.743213e+08     40.908040    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    35674.000000       35674.000000       28686.000000
# mean         7.395134          21.371027           1.144519
# std          9.216408          39.647157           1.298363
# ...

# %%
df4=df[((df['minimum_nights']>min_nights) & (df['price']>min_price) ) & ((df['minimum_nights']<max_nights) & (df['price']<max_price) )]

# %%
df4.head()
# Out:
#      id                                              name  host_id  host_name  \
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192      Laura
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322      Chris
# 7  5178                  Large Furnished Room Near B'way      8967   Shunichi
# 8  5203                Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 2           Manhattan           Harlem  40.80902  -73.94190     Private room
# 4           Manhattan      East Harlem  40.79851  -73.94399  Entire home/apt
# 5           Manhattan      Murray Hill  40.74767  -73.97500  Entire home/apt
# 7           Manhattan   Hell's Kitchen  40.76489  -73.98493     Private room
# 8           Manhattan  Upper West Side  40.80178  -73.96723     Private room
#
# ...

# %%
df4.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.525100e+04  3.525100e+04  35251.000000  35251.000000  35251.000000
# mean   1.868886e+07  6.170127e+07     40.728431    -73.955249    153.178775
# std    1.098122e+07  7.528901e+07      0.053177      0.042008    143.165714
# min    3.647000e+03  2.571000e+03     40.499790    -74.244420     31.000000
# 25%    9.236290e+06  6.493881e+06     40.690230    -73.983360     75.000000
# 50%    1.936459e+07  2.549878e+07     40.721980    -73.956990    120.000000
# 75%    2.862831e+07  9.486906e+07     40.762125    -73.939280    189.000000
# max    3.648724e+07  2.743213e+08     40.908040    -73.712990   2999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    35251.000000       35251.000000       28367.000000
# mean         7.373663          21.481433           1.147559
# std          9.206738          39.723378           1.301167
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(df4['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2696ecf56f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2696ecf5c30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2696ecf5450>],
#  'medians': [<matplotlib.lines.Line2D at 0x2696ecf6170>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2696ecf6410>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
plt.boxplot(df4['minimum_nights'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2696ed71210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2696ed71630>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2696ed70f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2696ed71b70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2696ed71e10>],
#  'means': []}

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df5=df[(df['price']>min_thresold) & (df['price']<max_thresold)]

# %%
df5.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df5.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.818300e+04  4.818300e+04  48183.000000  48183.000000  48183.000000
# mean   1.896272e+07  6.723035e+07     40.729155    -73.952498    148.772036
# std    1.099404e+07  7.851540e+07      0.054231      0.045894    153.594795
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     31.000000
# 25%    9.411247e+06  7.719674e+06     40.690355    -73.983190     70.000000
# 50%    1.960306e+07  3.038419e+07     40.723280    -73.955930    110.000000
# 75%    2.910493e+07  1.072455e+08     40.763180    -73.936960    179.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990   2999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48183.000000       48183.000000       38312.000000
# mean         7.011104          23.393915           1.373749
# std         20.526646          44.701116           1.680887
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(df5['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2696fa6a230>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2696fa6a9e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2696fa69a20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2696fa6b130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2696fa65360>],
#  'means': []}
